# %% [markdown]
# # You need to install
# yahoo_fin and
# requests_html

# %% [markdown]
# # Libraries that we will need

# %%
from yahoo_fin.stock_info import get_data
import pandas as pd
import yahoo_fin.stock_info as si
import yahoo_fin.options as ops

# %% [markdown]
# # Downloading One Ticket

# %%
Historical_Data = get_data("amzn", start_date="12/04/2009", end_date="12/04/2019", index_as_date = True, interval="1d")
Historical_Data
# Out:
#                    open         high          low        close     adjclose  \
# 2009-12-04   143.419998   143.449997   135.110001   137.580002   137.580002
# 2009-12-07   138.000000   139.000000   133.839996   134.210007   134.210007
# 2009-12-08   134.300003   136.080002   132.869995   134.110001   134.110001
# 2009-12-09   134.600006   134.710007   129.820007   131.309998   131.309998
# 2009-12-10   132.410004   136.190002   132.399994   135.380005   135.380005
# ...                 ...          ...          ...          ...          ...
# 2019-11-26  1779.920044  1797.030029  1778.349976  1796.939941  1796.939941
# 2019-11-27  1801.000000  1824.500000  1797.310059  1818.510010  1818.510010
# 2019-11-29  1817.780029  1824.689941  1800.790039  1800.800049  1800.800049
# 2019-12-02  1804.400024  1805.550049  1762.680054  1781.599976  1781.599976
# 2019-12-03  1760.000000  1772.869995  1747.229980  1769.959961  1769.959961
#
#               volume ticker
# ...

# %% [markdown]
# # Downloading Several Tickets

# %%
tickers = ["goog", "ko", "mmm"]

Historical_Data = {}
for t in tickers:
    Historical_Data[t] = get_data(t)
    
Historical_Data
# Out:
# {'goog':                    open         high          low        close     adjclose  \
#  2004-08-19    49.813286    51.835709    47.800831    49.982655    49.982655
#  2004-08-20    50.316402    54.336334    50.062355    53.952770    53.952770
#  2004-08-23    55.168217    56.528118    54.321388    54.495735    54.495735
#  2004-08-24    55.412300    55.591629    51.591621    52.239193    52.239193
#  2004-08-25    52.284027    53.798351    51.746044    52.802086    52.802086
#  ...                 ...          ...          ...          ...          ...
#  2020-06-10  1459.540039  1474.259033  1456.270020  1465.849976  1465.849976
#  2020-06-11  1442.479980  1454.474976  1402.000000  1403.839966  1403.839966
#  2020-06-12  1428.489990  1437.000000  1386.020020  1413.180054  1413.180054
#  2020-06-15  1390.800049  1424.800049  1387.920044  1419.849976  1419.849976
#  2020-06-16  1445.219971  1455.020020  1425.900024  1442.719971  1442.719971
#
#                volume ticker
# ...

# %% [markdown]
# # Getting the tickets that trade inside an especific index

# %%
dow_companies = si.tickers_dow()

print("Companies in the Dow Jones:", len(dow_companies))
dow_companies[0:15]
# Out:
# Companies in the Dow Jones: 30
# ['AAPL',
#  'AXP',
#  'BA',
#  'CAT',
#  'CSCO',
#  'CVX',
#  'DIS',
#  'DOW',
#  'GS',
#  'HD',
#  'IBM',
#  'INTC',
#  'JNJ',
#  'JPM',
#  'KO']

# %%
sp_companies = si.tickers_sp500()

print("Companies in sp500:", len(sp_companies))
sp_companies[0:15]
# Out:
# Companies in sp500: 505
# ['A',
#  'AAL',
#  'AAP',
#  'AAPL',
#  'ABBV',
#  'ABC',
#  'ABMD',
#  'ABT',
#  'ACN',
#  'ADBE',
#  'ADI',
#  'ADM',
#  'ADP',
#  'ADS',
#  'ADSK']

# %%
nasdaq_companies = si.tickers_nasdaq()

print("Companies in the NASDAQ:", len(nasdaq_companies))
nasdaq_companies[0:15]
# Out:
# Companies in the NASDAQ: 3515
# ['AAL',
#  'AAME',
#  'AAO',
#  'AAOI',
#  'AAPL',
#  'AAWW',
#  'AAX',
#  'AAXJ',
#  'ABCB',
#  'ABEO',
#  'ABIO',
#  'ABMD',
#  'ABTX',
#  'ABUS',
#  'ACAD']

# %% [markdown]
# # Some Fundamental Information

# %%
Fundamental_Info = si.get_quote_table("ko", dict_result = False)
Fundamental_Info
# Out:
#                    attribute                        value
# 0              1y Target Est                        52.16
# 1              52 Week Range                36.27 - 60.13
# 2                        Ask                  0.00 x 1400
# 3                Avg. Volume                  2.19065e+07
# 4          Beta (5Y Monthly)                         0.55
# 5                        Bid                  46.77 x 900
# 6                Day's Range                46.19 - 47.69
# 7                  EPS (TTM)                         2.32
# 8              Earnings Date  Jul 21, 2020 - Jul 27, 2020
# 9           Ex-Dividend Date                 Jun 12, 2020
# 10  Forward Dividend & Yield                 1.64 (3.51%)
# 11                Market Cap                     200.872B
# 12                      Open                        47.56
# 13            PE Ratio (TTM)                        20.16
# 14            Previous Close                         46.3
# ...

# %%
si.get_stats_valuation("ko")
# Out:
#                              0        1
# 0      Market Cap (intraday) 5  200.87B
# 1           Enterprise Value 3  230.26B
# 2                 Trailing P/E    20.16
# 3                Forward P/E 1    22.27
# 4  PEG Ratio (5 yr expected) 1    13.37
# 5            Price/Sales (ttm)     5.40
# 6             Price/Book (mrq)    11.06
# 7   Enterprise Value/Revenue 3     6.19
# 8    Enterprise Value/EBITDA 6    19.00

# %% [markdown]
# # Financial Statements

# %%
IS = si.get_income_statement("ko")
BS = si.get_balance_sheet("ko")
CF = si.get_cash_flow("ko")

# %%
IS
# Out:
#                                             Breakdown       ttm 12/31/2019  \
# 0                                       Total Revenue  37173000   37266000
# 1                                     Cost of Revenue  14625000   14619000
# 2                                        Gross Profit  22548000   22647000
# 3                                   Operating Expense  12070000   12114000
# 4                                    Operating Income  10478000   10533000
# 5           Net Non Operating Interest Income Expense   -352000    -383000
# 6                                Other Income Expense   1445000     636000
# 7                                       Pretax Income  11571000   10786000
# 8                                       Tax Provision   1494000    1801000
# 9                      Net Income Common Stockholders  10017000    8920000
# 10           Diluted NI Available to Com Stockholders  10017000    8920000
# ...

# %%
BS
# Out:
#                                   Breakdown 12/31/2019 12/31/2018 12/31/2017  \
# 0                              Total Assets   86381000   83216000   87896000
# 1   Total Liabilities Net Minority Interest   65283000   64158000   68919000
# 2      Total Equity Gross Minority Interest   21098000   19058000   18977000
# 3                      Total Capitalization   46497000   42345000   48254000
# 4                       Common Stock Equity   18981000   16981000   17072000
# 5                       Net Tangible Assets   -7785000    -289000     436000
# 6                           Working Capital   -6562000    1411000    9351000
# 7                          Invested Capital   61744000   60536000   64757000
# 8                       Tangible Book Value   -7785000    -289000     436000
# 9                                Total Debt   42763000   43555000   47685000
# 10                                 Net Debt   36283000   34629000   41679000
# ...

# %%
CF
# Out:
#                      Breakdown        ttm 12/31/2019 12/31/2018 12/31/2017  \
# 0          Operating Cash Flow   10239000   10471000    7627000    7106000
# 1          Investing Cash Flow    -601000   -3976000    5927000   -2450000
# 2          Financing Cash Flow   -1615000   -9004000  -10347000   -7447000
# 3            End Cash Position   14147000    6737000    9318000    6006000
# 4          Capital Expenditure   -1993000   -2054000   -1347000   -1675000
# 5    Issuance of Capital Stock    1235000    1012000    1476000    1595000
# 6             Issuance of Debt   25316000   23009000   27339000   29857000
# 7            Repayment of Debt  -20031000  -24850000  -30568000  -28768000
# 8  Repurchase of Capital Stock    -800000   -1103000   -1912000   -3682000
# 9               Free Cash Flow    8246000    8417000    6280000    5431000
#
#   12/31/2016
# 0    8796000
# 1    -999000
# 2   -6545000
# 3    8555000
# 4   -2262000
# 5    1434000
# 6   27281000
# 7  -25615000
# ...

# %% [markdown]
# # Option data

# %%
expiration_dates = ops.get_expiration_dates("WMT")
expiration_dates
# Out:
# ['June 19, 2020',
#  'June 26, 2020',
#  'July 2, 2020',
#  'July 10, 2020',
#  'July 17, 2020',
#  'July 24, 2020',
#  'July 31, 2020',
#  'August 21, 2020',
#  'September 18, 2020',
#  'December 18, 2020',
#  'January 15, 2021',
#  'June 18, 2021',
#  'January 21, 2022']

# %%
# Call Information
ops.get_calls("WMT")
# Out:
#          Contract Name         Last Trade Date  Strike  Last Price    Bid  \
# 0   WMT200619C00050000   2020-06-09 6:59PM EDT    50.0       74.00  69.00
# 1   WMT200619C00055000   2020-06-09 6:59PM EDT    55.0       75.00  64.15
# 2   WMT200619C00060000   2020-05-11 2:26PM EDT    60.0       63.80  59.60
# 3   WMT200619C00065000   2020-06-09 6:59PM EDT    65.0       53.81  52.35
# 4   WMT200619C00070000  2020-05-26 10:44AM EDT    70.0       55.00   0.00
# 5   WMT200619C00075000  2020-06-05 11:42AM EDT    75.0       46.35   0.00
# 6   WMT200619C00080000   2020-05-26 3:34PM EDT    80.0       43.90   0.00
# 7   WMT200619C00085000   2020-05-21 1:40PM EDT    85.0       39.45   0.00
# 8   WMT200619C00087500  2020-05-18 12:49PM EDT    87.5       39.75   0.00
# 9   WMT200619C00090000  2020-05-27 12:57PM EDT    90.0       31.61   0.00
# 10  WMT200619C00092500  2020-05-20 11:05AM EDT    92.5       33.70   0.00
# 11  WMT200619C00095000  2020-06-16 12:09PM EDT    95.0       24.20   0.00
# ...

# %%
# Put Information
ops.get_puts("WMT")
# Out:
#          Contract Name         Last Trade Date  Strike  Last Price  Bid  Ask  \
# 0   WMT200619P00050000   2020-06-10 9:30AM EDT    50.0        0.01  0.0  0.0
# 1   WMT200619P00055000   2020-05-27 9:49AM EDT    55.0        0.01  0.0  0.0
# 2   WMT200619P00060000   2020-06-10 9:32AM EDT    60.0        0.01  0.0  0.0
# 3   WMT200619P00065000   2020-05-18 2:09PM EDT    65.0        0.03  0.0  0.0
# 4   WMT200619P00070000  2020-06-15 10:22AM EDT    70.0        0.01  0.0  0.0
# 5   WMT200619P00075000   2020-06-16 9:30AM EDT    75.0        0.01  0.0  0.0
# 6   WMT200619P00080000  2020-06-12 10:53AM EDT    80.0        0.03  0.0  0.0
# 7   WMT200619P00085000   2020-06-11 3:40PM EDT    85.0        0.03  0.0  0.0
# 8   WMT200619P00087500   2020-06-11 3:42PM EDT    87.5        0.03  0.0  0.0
# 9   WMT200619P00090000   2020-06-15 9:30AM EDT    90.0        0.07  0.0  0.0
# 10  WMT200619P00092500   2020-06-16 3:19PM EDT    92.5        0.01  0.0  0.0
# ...
